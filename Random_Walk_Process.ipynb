# %% [markdown]
# # 확률보행과정(Random Walk Process)
#
# 확률보행과정은 술취한 사람이 어디로 갈지 모르는 것처럼 대표적인 불안정 시계열 확률과정입니다.<br/>

# %%
library(forecast)

x <- rnorm(300)
w <- x

for (t in 2:300){
    x[t] = x[t-1] + w[t] # random walk process
}
x.ts <- ts(x)

ggtsdisplay(x.ts)
ggAcf(x.ts)
ggPacf(x.ts)
# Out:
# Warning message:
# "package 'forecast' was built under R version 3.6.3"
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# plot without title
# plot without title
# plot without title
