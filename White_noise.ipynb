# %% [markdown]
# # White noise
#
# 확률과정들이 서로 독립이고 동일한 분포를 가지며 평균을 일반적으로 0으로 가정하며 분산도 일정한 정상성을 갖도록 하는 것을 백색잡음과정(white noise series or pure stochastic process)라고 합니다.<br/>

# %%
library(forecast)
library(ggplot2)

set.seed(12)
y <- ts(rnorm(50))
autoplot(y) + ggtitle("White noise")

ggAcf(y)
ggPacf(y)
ggtsdisplay(y)
# Out:
# Warning message:
# "package 'forecast' was built under R version 3.6.3"
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# plot without title
# plot without title
# plot without title
# plot without title
